# %%
import requests
from bs4 import BeautifulSoup
import lxml.html
import webbrowser
import pandas as pd

# %%
#Edge
titles = ["Title","Date","Contents"]
df1 = pd.DataFrame(columns = titles)


i=1
for page_name in ["", "?page=1" ]:
    url = 'http://www.theedgemarkets.com/search-results' + page_name
        
    page = requests.get(url)
    html = page.content
    soup = BeautifulSoup(html, "lxml")
    containers = soup.findAll("div",{"class":"views-row"})

    for container in containers:

        
    
        title_container = container.find("div",{"class":"views-field views-field-title"})

#article name    
        article_name = title_container.span.a.text

#article link
        news_link = "http://www.theedgemarkets.com" + title_container.span.a['href']

        sub_page = requests.get(news_link)
        sub_html = sub_page.content
        sub_soup = BeautifulSoup(sub_html,"lxml")

#article date
        article_date = sub_soup.find("span",{"class":"post-created"}).text

#article content
        article_text = ''
        article = sub_soup.findAll("div",{"property":"content:encoded"})
        for p in article:
            article_text += ''.join(p.findAll(text = True))
    
        df1.loc[i] = [article_name, article_date, article_text]
        i = i + 1
i+1

path = "E:/Training Python with Spacy 31 august 2018/webscrapper/Edge.xlsx"
df1.to_excel(path)

# %%
df1
# Out:
#                                                 Title  \
# 1   Foreign bond investors' risk aversion unlikely...
# 2                                         “我受指示离马避调查”
# 3   Passengers tell govts to focus on sustainable ...
# 4             Weekend by numbers 21.06.19 to 23.06.19
# 5   MACC files civil forfeiture suit against 41 en...
# 6   My Say: Will tomorrow thank us for today’s act...
# 7                          接获1830万的催款通知 Seacera跌2.33%
# 8   Lower finance cost seen to boost MBM Resources...
# 9   Demand for FPSO expected to be exceptionally s...
# 10  Foxconn chairman hands over reins ahead of pre...
# 11  Travel insurance seen to be Tune Protect’s ear...
# 12  Small amounts over a period of time seen the w...
# 13  AG: 25 more prosecution witnesses in Najib-SRC...
# 14  Low inflation, macroeconomic fundamentals coul...
# 15  Dayang’s recent contract wins may help get mor...
# 16  Slack stock surges at debut, values company at...
# 17  Serba Dinamik targets 10% net profit growth in...
# 18                         撤销对财政部的司法复核申请 云顶马来西亚跌1.78%
# 19  OCBC sees ringgit at RM4.16 against US dollar ...
# 20  Seacera falls 2.33% after getting letter of de...
# 21  Hong Kong Government Closes Headquarters as Pr...
# 22  Gan claims he only knew about overstated reven...
# 23  Some RM212m to be recovered by MACC were disbu...
# 24  MACC files civil forfeiture suit against 41 en...
# 25  HLIB bullish on Alliance Bank as share price s...
# 26  Most of KWAP’s RM4b loan to SRC spent — ex-dir...
# 27  Witness agrees Najib should have left cabinet ...
# 28                     ‘I was told SRC belongs to PM’
# 29                                   云升涨6.71% 至23年来最高
# 30  Genting Malaysia active, dips 1.78% on withdra...
# 31     5.78% stake in RHB Bank transacted off- market
# 32    ‘Cement not the cause of higher housing prices’
# 33    Palm oil biased to retest resistance at RM2,068
# 34  Sports Direct, Jeffrey Cheah named winners at ...
# 35                                  马股跌幅收窄 料以疲势结束本周交易
# 36  Gold futures top $1,400 for first time since 2...
# 37  Yinson shares rise 6.71% to highest level in 2...
# 38  Australia's Lynas stockpiles rare earths for '...
# 39          Aeon Credit hopes to maintain bottom line
# 40  Malaysia keeps July crude palm oil export duty...
# 41  Kerjaya Prospek lands RM227m Bukit Bintang dev...
# 42  Genting Malaysia withdraws judicial review aga...
#
#                           Date  \
# 1   June 21, 2019 11:55 am +08
# 2   June 21, 2019 11:43 am +08
# 3   June 21, 2019 11:43 am +08
# 4   June 21, 2019 11:39 am +08
# 5   June 21, 2019 11:37 am +08
# 6   June 21, 2019 11:30 am +08
# 7   June 21, 2019 11:24 am +08
# 8   June 21, 2019 11:23 am +08
# 9   June 21, 2019 11:21 am +08
# 10  June 21, 2019 11:20 am +08
# 11  June 21, 2019 11:19 am +08
# 12  June 21, 2019 11:18 am +08
# 13  June 21, 2019 11:17 am +08
# 14  June 21, 2019 11:17 am +08
